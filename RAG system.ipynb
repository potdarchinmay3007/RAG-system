# %% [markdown]
# <a href="https://colab.research.google.com/github/potdarchinmay3007/RAG-system/blob/main/RAG%20system.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Section B — RAG Fundamentals
#B1. Fixed-Size Chunking with Overlap
#Question: Take a small corpus of 5–6 short paragraphs. Split it into fixed-size chunks with some overlap. Print the chunks and explain why you chose that chunk size and overlap.
#Answer: I created a small text corpus and divided it into fixed-size chunks. I used 100 characters as the chunk size and 20 characters as overlap. The overlap helps to keep some context between two consecutive chunks, so important information is not lost at the boundary.

text = """
Artificial Intelligence allows computers to perform tasks that normally
require human intelligence. Machine learning is a part of AI that learns
patterns from data.
RAG stands for Retrieval Augmented Generation. It retrieves relevant
information from a knowledge source before generating an answer.
Vector databases are used to store numerical representations called
embeddings. These embeddings help find similar pieces of information.
Chunking means breaking a large document into smaller pieces. It makes
documents easier to search and retrieve.
Dense retrieval converts text into embeddings and finds information based
on semantic similarity. """

#make chunks, embeddings from this data and search for it......
chunk_size = 100
overlap = 20
chunks = []
for i in range(0, len(text), chunk_size - overlap):
    chunks.append(text[i:i + chunk_size])

# This makes chunks of the data, and they overlap with each other by 20 characters cause we need  to connect the chuncks if there is an imp. sentence at the end will get divide that's why we need to overlap the chunks.
#so the next chunk will be of 80 charecters
for chunk in chunks:
    print(chunk)
# Out:
# Artificial Intelligence allows computers to perform tasks that normally
# require human intelligence.
#  human intelligence. Machine learning is a part of AI that learns
# patterns from data.
# RAG stands for
# data.
# RAG stands for Retrieval Augmented Generation. It retrieves relevant
# information from a knowle
# mation from a knowledge source before generating an answer.
# Vector databases are used to store numer
#  used to store numerical representations called
# embeddings. These embeddings help find similar piece
# p find similar pieces of information.
# Chunking means breaking a large document into smaller pieces.
# nto smaller pieces. It makes
# documents easier to search and retrieve.
# Dense retrieval converts text
# ieval converts text into embeddings and finds information based
# on semantic similarity.
# larity.

# %%
#B2. Dense Retrieval
#Question=> Use an embedding model to create embeddings for the chunks. Retrieve the top-3 chunks using cosine similarity. Test it with 2 queries.
#Answer=> For dense retrieval, I converted the chunks and queries into embeddings using an embedding model. Then I used cosine similarity to find which chunks were most similar to each query. Finally, I returned the top-3 chunks. The chunks with the highest cosine similarity are considered the most relevant results for the query.

# %%
#B3. BM25 Retrieval
#Question: Run BM25 on the same chunks for the same 2 queries. Compare the results with dense retrieval.
#Answer=> BM25 is a keyword-based retrieval method. It checks the words present in the query and finds chunks containing important matching words. I used the same chunks and queries as in dense retrieval.
